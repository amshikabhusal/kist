# %%
class bank_account:
    def __init__(self,balance):
        self.__balance = balance

    def deposit(self, amount):
        if amount <= 0:
            return 'Invalid Deposit'
        self.__balance = self.__balance + amount
        # self.__balance += amount
        return f'Rs.{amount} Deposited and final balance after deposit is Rs.{self.__balance}'

    def withdraw(self, amount):
        if self.__balance >= amount:
            self.__balance = self.__balance - amount
            # self.__balance -= amount
            return f'Rs.{self.__balance} left in bank account after Rs.{amount} is withdrawn.The total amount in the bank before withdraw was Rs.{self.__balance + amount}'
        else:
            return 'Invalid Withdrawl since the required amount is not in the account'

    def get_balance(self):
        return f'The total balance in your account is Rs.{self.__balance}'

# %%
diwas = bank_account()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 diwas = bank_account()
#
# TypeError: bank_account.__init__() missing 1 required positional argument: 'balance'

# %%
diwas = bank_account(1000)

# %%
diwas.get_balance()
# Out:
# 'The total balance in your account is Rs.1000'

# %%
diwas.deposit(5000)
# Out:
# 'Rs.5000 Deposited and final balance after deposit is Rs.6000'

# %%
diwas.get_balance()
# Out:
# 'The total balance in your account is Rs.6000'

# %%
diwas.deposit(1000)
# Out:
# 'Rs.1000 Deposited and final balance after deposit is Rs.7000'

# %%
diwas.get_balance()
# Out:
# 'The total balance in your account is Rs.7000'

# %%
diwas.withdraw(7001)
# Out:
# 'Invalid Withdrawl since the required amount is not in the account'

# %%
diwas.withdraw(4000)
# Out:
# 'Rs.3000 left in bank account after Rs.4000 is withdrawn.The total amount in the bank before withdraw was Rs.7000'

# %%
diwas.withdraw(4000)
# Out:
# 'Invalid Withdrawl since the required amount is not in the account'

# %%
diwas.get_balance()
# Out:
# 'The total balance in your account is Rs.1000'

# %%
rajesh = bank_account(5000)

# %%
rajesh.deposit(10000)

# %%
rajesh.get_balance()

# %%
rajesh.deposit(-5000)

# %%
rajesh.get_balance()

# %%
rajesh.withdraw(20000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 rajesh.withdraw(20000)
#
# NameError: name 'rajesh' is not defined

# %%
rajesh.withdraw(2000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 rajesh.withdraw(2000)
#
# NameError: name 'rajesh' is not defined

# %%
rajesh.get_balance()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 rajesh.get_balance()
#
# NameError: name 'rajesh' is not defined

# %%
Amshika = bank_account(100000)

# %%
Amshika.deposit(10000)
# Out:
# 'Rs.10000 Deposited and final balance after deposit is Rs.110000'

# %%
Amshika.withdraw(50000)
# Out:
# 'Rs.60000 left in bank account after Rs.50000 is withdrawn.The total amount in the bank before withdraw was Rs.110000'

# %%
Amshika.get_balance()
# Out:
# 'The total balance in your account is Rs.60000'
